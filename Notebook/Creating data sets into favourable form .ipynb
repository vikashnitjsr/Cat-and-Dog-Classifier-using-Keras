# %% [markdown]
# ## Open cv  functions

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
t=cv2.imread("./pets/Cat/1.jpg")

# %%
cv2.imshow("image",t)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Dog and Cat Classifier

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
DATADIR="./pets"

# %%
CATEGORIES=["Dog","Cat"]

# %%
for i in CATEGORIES:
    path=os.path.join(DATADIR,i)
    print(os.listdir(path))
# Out:
# ['0.jpg', '1.jpg', '10.jpg', '100.jpg', '1000.jpg', '10000.jpg', '10001.jpg', '10002.jpg', '10003.jpg', '10004.jpg', '10005.jpg', '10006.jpg', '10007.jpg', '10008.jpg', '10009.jpg', '1001.jpg', '10010.jpg', '10011.jpg', '10012.jpg', '10013.jpg', '10014.jpg', '10015.jpg', '10016.jpg', '10017.jpg', '10018.jpg', '10019.jpg', '1002.jpg', '10020.jpg', '10021.jpg', '10022.jpg', '10023.jpg', '10024.jpg', '10025.jpg', '10026.jpg', '10027.jpg', '10028.jpg', '10029.jpg', '1003.jpg', '10030.jpg', '10031.jpg', '10032.jpg', '10033.jpg', '10034.jpg', '10035.jpg', '10036.jpg', '10037.jpg', '10038.jpg', '10039.jpg', '1004.jpg', '10040.jpg', '10041.jpg', '10042.jpg', '10043.jpg', '10044.jpg', '10045.jpg', '10046.jpg', '10047.jpg', '10048.jpg', '10049.jpg', '1005.jpg', '10050.jpg', '10051.jpg', '10052.jpg', '10053.jpg', '10054.jpg', '10055.jpg', '10056.jpg', '10057.jpg', '10058.jpg', '10059.jpg', '1006.jpg', '10060.jpg', '10061.jpg', '10062.jpg', '10063.jpg', '10064.jpg', '10065.jpg', '10066.jpg', '10
# ...

# %%
for i in CATEGORIES:
    path=os.path.join(DATADIR,i)
    #print(os.listdir(path))
    for j in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,j)) #cv2.IMREAD_GRAYSCALE
        #img_arr=cv2.imread(os.path.join(path,j),cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_array ,cmap="gray")
        plt.show()
        break
    #break

# %% [markdown]
# - ### image matrix 1

# %%
print(img_array)
# Out:
# [[[ 87 164 203]
#   [ 87 164 203]
#   [ 88 165 204]
#   ...
#   [122 201 240]
#   [121 200 239]
#   [120 199 238]]
#
#  [[ 87 164 203]
#   [ 87 164 203]
#   [ 88 165 204]
#   ...
#   [122 201 240]
#   [121 200 239]
#   [121 200 239]]
#
#  [[ 87 164 203]
#   [ 87 164 203]
#   [ 88 165 204]
#   ...
#   [123 202 241]
#   [122 201 240]
#   [121 200 239]]
#
#  ...
#
#  [[ 55 122 153]
#   [ 55 122 153]
#   [ 55 122 153]
#   ...
#   [  0   2   2]
#   [  0   2   2]
#   [  0   2   2]]
#
#  [[ 54 121 152]
#   [ 54 121 152]
#   [ 54 121 152]
#   ...
#   [  0   1   1]
#   [  0   1   1]
#   [  0   1   1]]
#
#  [[ 53 120 151]
#   [ 53 120 151]
#   [ 54 121 152]
#   ...
#   [  0   1   1]
#   [  0   1   1]
#   [  0   1   1]]]

# %%
img_array.shape
# Out:
# (375, 500, 3)

# %%
# plt.matshow()
for i in CATEGORIES:
    path=os.path.join(DATADIR,i)
    #print(os.listdir(path))
    for j in os.listdir(path):
        #img_arr=cv2.imread(os.path.join(path,j)) #cv2.IMREAD_GRAYSCALE
        img_array=cv2.imread(os.path.join(path,j),cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_array ,cmap="gray")
        plt.show()
        break
    #break

# %% [markdown]
# - ### Image matrix 2

# %%
img_array.shape
#shape of the image matrix
# Out:
# (375, 500, 3)

# %%
img_size=50
new_array=cv2.resize(img_array,(img_size,img_size))
plt.imshow(new_array,cmap="gray")
plt.show()

# %%
DATADIR="./pets"
CATEGORIES=["Dog","Cat"]
from tqdm import tqdm
training_data=[]
for i in CATEGORIES:
    path=os.path.join(DATADIR,i)
    class_no=CATEGORIES.index(i)
    for j in tqdm(os.listdir(path)):
        try:
            img_arr=cv2.imread(os.path.join(path,j),cv2.IMREAD_GRAYSCALE)
            new_array=cv2.resize(img_array,(img_size,img_size))
            training_data.append([new_array,class_no])
        except Exception as e:
            pass
'''
DATADIR="./pets"
CATEGORIES=["Dog","Cat"]
training_data = []
for i in CATEGORIES:
    path = os.path.join(DATADIR,i) 
    class_num = CATEGORIES.index(i)
    print(class_num)
    for j in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,j) ,cv2.IMREAD_GRAYSCALE) 
        new_array = cv2.resize(img_array, (img_size,img_size))
        print([new_array, class_num])
        training_data.append([new_array, class_num])
        #except Exception as e:
         #   pass'''
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12501/12501 [03:57<00:00, 47.35it/s]
# '\nDATADIR="./pets"\nCATEGORIES=["Dog","Cat"]\ntraining_data = []\nfor i in CATEGORIES:\n    path = os.path.join(DATADIR,i) \n    class_num = CATEGORIES.index(i)\n    print(class_num)\n    for j in os.listdir(path):\n        img_array = cv2.imread(os.path.join(path,j) ,cv2.IMREAD_GRAYSCALE) \n        new_array = cv2.resize(img_array, (img_size,img_size))\n        print([new_array, class_num])\n        training_data.append([new_array, class_num])\n        #except Exception as e:\n         #   pass'

# %%
print(len(training_data))
# Out:
# 25002

# %%
import random
random.shuffle(training_data)
print(training_data[:10])
# Out:
# [[array([[[ 91, 168, 207],
#         [100, 177, 216],
#         [104, 183, 224],
#         ...,
#         [145, 219, 249],
#         [133, 211, 247],
#         [122, 205, 243]],
#
#        [[ 92, 169, 208],
#         [ 99, 176, 215],
#         [104, 183, 224],
#         ...,
#         [145, 220, 249],
#         [139, 214, 246],
#         [129, 210, 245]],
#
#        [[ 93, 167, 209],
#         [101, 175, 217],
#         [101, 177, 219],
#         ...,
#         [142, 219, 248],
#         [135, 218, 246],
#         [137, 215, 244]],
#
#        ...,
#
#        [[ 62, 130, 165],
#         [ 66, 134, 169],
#         [ 66, 137, 174],
#         ...,
#         [  1,   6,   5],
#         [  0,   5,   4],
#         [  0,   5,   4]],
#
#        [[ 58, 126, 161],
#         [ 62, 130, 165],
#         [ 62, 133, 170],
#         ...,
#         [  0,   4,   3],
#         [  0,   4,   3],
#         [  0,   4,   3]],
#
#        [[ 57, 124, 155],
#         [ 61, 128, 159],
#         [ 60, 132, 166],
# ...

# %%
for i in training_data[:10]:
    print(i)
# Out:
# [array([[[ 91, 168, 207],
#         [100, 177, 216],
#         [104, 183, 224],
#         ...,
#         [145, 219, 249],
#         [133, 211, 247],
#         [122, 205, 243]],
#
#        [[ 92, 169, 208],
#         [ 99, 176, 215],
#         [104, 183, 224],
#         ...,
#         [145, 220, 249],
#         [139, 214, 246],
#         [129, 210, 245]],
#
#        [[ 93, 167, 209],
#         [101, 175, 217],
#         [101, 177, 219],
#         ...,
#         [142, 219, 248],
#         [135, 218, 246],
#         [137, 215, 244]],
#
#        ...,
#
#        [[ 62, 130, 165],
#         [ 66, 134, 169],
#         [ 66, 137, 174],
#         ...,
#         [  1,   6,   5],
#         [  0,   5,   4],
#         [  0,   5,   4]],
#
#        [[ 58, 126, 161],
#         [ 62, 130, 165],
#         [ 62, 133, 170],
#         ...,
#         [  0,   4,   3],
#         [  0,   4,   3],
#         [  0,   4,   3]],
#
#        [[ 57, 124, 155],
#         [ 61, 128, 159],
#         [ 60, 132, 166],
# ...

# %%
X = []
y = []

for features,label in training_data:
    X.append(features)
    y.append(label)

print(X[0].reshape(-1,img_size, img_size, 1))

X = np.array(X).reshape(-1, img_size, img_size, 1)
# Out:
# [[[[ 91]
#    [168]
#    [207]
#    ...
#    [206]
#    [  6]
#    [ 83]]
#
#   [[151]
#    [ 21]
#    [104]
#    ...
#    [223]
#    [251]
#    [140]]
#
#   [[223]
#    [251]
#    [140]
#    ...
#    [122]
#    [205]
#    [243]]
#
#   ...
#
#   [[109]
#    [195]
#    [ 36]
#    ...
#    [137]
#    [218]
#    [253]]
#
#   [[ 85]
#    [159]
#    [201]
#    ...
#    [209]
#    [  0]
#    [118]]
#
#   [[217]
#    [  0]
#    [134]
#    ...
#    [ 79]
#    [163]
#    [  1]]]
#
#
#  [[[111]
#    [195]
#    [ 46]
#    ...
#    [136]
#    [217]
#    [252]]
#
#   [[ 83]
#    [160]
#    [199]
#    ...
#    [178]
#    [  2]
#    [110]]
#
#   [[192]
#    [  2]
#    [123]
#    ...
#    [ 83]
#    [165]
#    [  2]]
#
#   ...
#
#   [[ 91]
#    [  3]
#    [ 45]
#    ...
#    [ 82]
#    [125]
#    [  4]]
#
#   [[ 82]
#    [125]
#    [ 16]
#    ...
#    [ 15]
#    [ 56]
#    [ 81]]
#
#   [[ 81]
#    [158]
#    [197]
#    ...
#    [116]
#    [  6]
#    [ 71]]]
#
#
#  [[[100]
#    [  6]
#    [ 56]
# ...

# %% [markdown]
# - ## Saving the Features (X)  and respons or label as (y)

# %%
import pickle

pickle_out = open("X.pickle","wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle","wb")
pickle.dump(y, pickle_out)
pickle_out.close()
#We can always load it in to our current script, or a totally new one by doing:

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

# %% [markdown]
# - ## Input image Matrix form (Feature matrix)

# %%
X[1].shape
# Out:
# (50, 50, 1)

# %% [markdown]
# - ## Response Vector (Predicted lable or value corresponding to image matrix)

# %%
y[1]
# Out:
# 0
